# %%
import numpy as np
import pandas as pd 

from pandas import Series , DataFrame

# %%
import webbrowser
website = "https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records#Regular_season"
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1920  NFC North
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL Season']
# Out:
# 0    1960
# 1    1920
# 2    1921
# 3    1960
# 4    1966
# Name: First NFL Season, dtype: int64

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'Pct.'])
# Out:
#                       Team  First NFL Season   Pct.
# 0           Dallas Cowboys              1960  0.573
# 1            Chicago Bears              1920  0.564
# 2        Green Bay Packers              1921  0.564
# 3  New England Patriots[b]              1960  0.561
# 4           Miami Dolphins              1966  0.556

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1920  NFC North
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
nfl_frame.tail()
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1920  NFC North
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
nfl_frame.iloc[3]
# Out:
# Rank                                      4
# Team                New England Patriots[b]
# GP                                      900
# Won                                     500
# Lost                                    391
# Tied                                      9
# Pct.                                  0.561
# First NFL Season                       1960
# Division                           AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Division'] = "Levies's Stadium"

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season          Division
# 0              1960  Levies's Stadium
# 1              1920  Levies's Stadium
# 2              1921  Levies's Stadium
# 3              1960  Levies's Stadium
# 4              1966  Levies's Stadium

# %%
nfl_frame['Division']=np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season  Division
# 0              1960         0
# 1              1920         1
# 2              1921         2
# 3              1960         3
# 4              1966         4

# %%
divisions = Series(["levies stadium","at&T stadium"], index = [4,0])

# %%
divisions
# Out:
# 4    levies stadium
# 0      at&T stadium
# dtype: object

# %%
nfl_frame['Division']=divisions

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season        Division
# 0              1960    at&T stadium
# 1              1920             NaN
# 2              1921             NaN
# 3              1960             NaN
# 4              1966  levies stadium

# %%
del nfl_frame['Division']

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season
# 0              1960
# 1              1920
# 2              1921
# 3              1960
# 4              1966

# %%
data = {'city':["sf",'la','nyc'], 'Population':[837000,3880000,8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   city  Population
# 0   sf      837000
# 1   la     3880000
# 2  nyc     8400000
